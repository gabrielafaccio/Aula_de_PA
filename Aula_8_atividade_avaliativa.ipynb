# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_8_atividade_avaliativa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que verifica se o número digitado é par ou impar

# Entrada

numero = int (input("Digite um número: "))


# Processamento / Saída

if numero % 2 == 0:

  print (f"O número {numero} é par. ")
,
else:
  print (f"O número {numero} é impar. ")
# Out:
# Digite um número: 10
# O número 10 é par.

# %%
# Solicite dois números e mostre qual é o maior (ou se são iguais).

# Entrada

numero1 = float (input("Digite o primeiro número: "))
numero2 = float (input("Digite o segundo número: "))

# Processamento / Saída

if numero1 > numero2:

  print (f"O primeiro número {numero1} é maior. ")

elif numero2 > numero1:
   print(f" O segundo número {numero2} é maior")

else:
  print (f"Os dois número são iguais. ")
# Out:
# Digite o primeiro número: 10
# Digite o segundo número: 2
# O primeiro número 10.0 é maior.

# %%
# Escrever um programa que verifica as notas do aluno e calcula a média do aluno

# Entrada

nota_1 = float(input ("Digite a nota do 1° Bimestre "))
if nota_1 < 0 or nota_1 > 10:
  print("nota inválida, digite uma nota de 0 a 10:")


nota_2 = float(input ("Digite a nota do 2° Bimestre "))
if nota_2 < 0 or nota_2 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")


nota_3 = float(input ("Digite a nota do 3° Bimestre "))
if nota_3 < 0 or nota_3 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")

nota_4 = float(input ("Digite a nota do 4° Bimestre "))
if nota_4 < 0 or nota_4 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")

# Processamento/Saída

media = (nota_1 + nota_2 + nota_3 + nota_4) /4

if media < 5:
    print(f"Você está reprovado, sua media é :{media} ")

elif media <= 7:
    print(f"Você está de recuperação, sua mediaa é {media}")

else:
    print(f"Você está aprovado, sua media é {media}")
# Out:
# Digite a nota do 1° Bimestre 10
# Digite a nota do 2° Bimestre 10
# Digite a nota do 3° Bimestre 10
# Digite a nota do 4° Bimestre 10
# Você está aprovado, sua media é 10.0

# %%
# Escrever um programa que verifica se a idade corresponde a uma criança, adolescente adulto ou idoso

# Entrada
nome = str (input(" Digite o seu nome: "))
idade = float (input(" Digite sua idade: "))

# Processamento / Saída

if idade <= 12 :
  print (f"{nome}, você é uma Criança ")

elif idade <= 17 :
  print (f"{nome}, voce é um  Adolecente")

elif idade <= 59:
     print (f"{nome}, você é um  Adulto")

else:
  print (f"{nome}, você é um  idoso")
# Out:
#  Digite o seu nome: Elizabete
#  Digite sua idade: 7
# Elizabete, você é uma Criança

# %%
# Senha correta
# Defina uma senha fixa no código. Peça ao usuário para digitar e informe se está correta ou incorreta.

# Entrada

senha_certa = "3293"

senha = input("Digite a senha ")

# Processamento/Saída

if senha == senha_certa :
   print(f"Senha certa, acesso liberado")

else:
    print(f"Senha incorreta, digite novamente")
# Out:
# Digite a senha 3293
# Senha certa, acesso liberado

# %%
# Positivo, negativo ou zero
# Peça um número e diga se ele é positivo, negativo ou zero.

# Entrada

numero = float(input("Digite um número "))

# Processamento/Saída

if numero > 0:
  print(f"O número é positivo")

elif numero < 0 :
  print (f"O número é negativo")

else:
   print(f" O Númnero é zero")
# Out:
# Digite um número -8
# O número é negativo

# %%
# Escrever um programa de uma calculadora simples.

# Entrada

print ("|----------- CALCULADORA-----------|")
print ("|                                  |")
print ("|---------------MENU---------------|")
print ("|                                  |")
print ("| Opção = 1 - Soma                 |")
print ("| Opção = 2 - Subtração            |")
print ("| Opção = 3 - Multiplicação        |")
print ("| Opção = 4 - Divisão              |")
print ("|----------------------------------|")


# Entrada
numero = float (input("Digite um numero: "))
opcao = int (input ("Escolha a opção desejada: "))
numero1 = float (input("Digite um numero: "))

# Processamento/ Saída

if opcao == 1:
  print (f"A soma de {numero} e {numero1} é igual a {numero + numero1} :")

elif opcao == 2:
  print (f"A subtração de {numero} e {numero1} é igual a {numero - numero1} :")

elif opcao == 3:
  print (f"A multiplicação de {numero} e {numero1} é igual a {numero * numero1} :")

elif opcao == 4:
  print (f"A divisão de {numero} e {numero1} é igual a {numero / numero1} :")

else:
  print (" Opção inválida")
# Out:
# |----------- CALCULADORA-----------|
# |                                  |
# |---------------MENU---------------|
# |                                  |
# | Opção = 1 - Soma                 |
# | Opção = 2 - Subtração            |
# | Opção = 3 - Multiplicação        |
# | Opção = 4 - Divisão              |
# |----------------------------------|
# Digite um numero: 12
# Escolha a opção desejada: 4
# Digite um numero: 3
# A divisão de 12.0 e 3.0 é igual a 4.0 :

# %%
# Dia da semana
# Peça um número de 1 a 7 e mostre o dia correspondente (ex: 1 = domingo).

# Entrada
numero = int(input(f"Digite um número de 1 a 7 "))

# Processamento/Saída

if numero == 1:
  print(f"Hoje é Domingo")

elif numero == 2:
  print (f"Hoje é Segunda - Feira")

elif numero == 3:
  print (f"Hoje é Terça - Feira")

elif numero == 4:
  print (f"Hoje é Quarta - Feira")

elif numero == 5:
  print (f"Hoje é Quinta - Feira")

elif numero == 6:
  print (f"Hoje é Sexta - Feira")

elif numero == 7:
  print (f"Hoje é Sábado")

else:
   print(f"Número inválido")
# Out:
# Digite um número de 1 a 7 9
# Número inválido

# %%
# Verificar se o ano e bissexto ou não

# Entrada

ano = int(input("Digite um ano  "))

# Processamento/Saída

if ano % 400 == 0:
   print (f"O ano é bissexto ")

elif ano % 100 == 0:
    print(f"O ano não é bissexto")

elif ano % 4 == 0:
   print(f" O ano é bissexto")

else:
    print(f"O ano não é bissexto")
# Out:
# Digite um ano  2024
#  O ano é bissexto

# %%
# Calcular o desconto

# Entrada
compra= float(input("Digite o valor da sua compra: R$ "))

desconto = compra - (compra * 0.10)


# Processamento/Saída

if compra > 100:
  desconto = compra - (compra * 0.10)
  print(f" O valor a pagar é:{desconto}")


elif compra > 500:
  desconto = compra - (compra * 0.20)
  print(f" O valor a pagar com desconto é:{desconto}")

else:
  print(f"Você não obteve desconto, o valor a pagar: {comnpra}")
# Out:
# Digite o valor da sua compra: R$ 120
#  O valor a pagar é:108.0
