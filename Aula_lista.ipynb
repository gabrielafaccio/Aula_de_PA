# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTA

# %%
Alunos = ["letícia", "Anderson", "Marcos"]
Alunos [1] = "Márcia"
print (Alunos)
# SUBSITUIR NOME DA LISTA
# Out:
# ['letícia', 'Márcia', 'Marcos']

# %%
Alunos = ["letícia", "Anderson", "Marcos"]
Alunos.append("Rafaella")
print(Alunos)
#ADICIONAR NOME A LISTA
# Out:
# ['letícia', 'Anderson', 'Marcos', 'Rafaella']

# %%
Alunos = ["letícia", "Anderson", "Marcos"]
Alunos.remove("letícia")
print (Alunos)
# REMOVER NOME DA LISTA
# Out:
# ['Anderson', 'Marcos']

# %% [markdown]
# SISTEMA DE DADOS
# LISTA [
# TUPLA ( NÃO DA PARA ALTERAR

# %% [markdown]
#                              tupla

# %%
Alunos = ("Ana", 17, "Informática")
print (Alunos[2])
# Out:
# Informática

# %% [markdown]
# EXERCÍCIOS

# %%
Frutas = ["Maçã", "Banana", "Laranja", "Morango"]
print (Frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
cores = ["vermelho", "azul", "verde"]
cores [1]= "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
alunos =["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print (animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# TUPLA

# %%
ano = ("Janeiro", "Fevereiro", "Março", "Abril")
print (ano)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
numeros = (10, 20, 30, 40, 50)
print (numeros[0])
print (numeros[2])
print (numeros[4])
# Out:
# 10
# 30
# 50

# %%
Alunos = ("Gabriela", 16, "Informática para internet")
print (Alunos[0])
print (Alunos[1])
print (Alunos[2])
# Out:
# Gabriela
# 16
# Informática para internet

# %%
cores = ("vermelho", "azul", "verde")
cores.append("Lilás")
print (cores)
# não vai ir por conta que a tupla não aceita substituir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2048/80672009.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
# ----> 2 cores.append("Lilás")
#       3 print (cores)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)
numeros.count(2)
# Out:
# 3
