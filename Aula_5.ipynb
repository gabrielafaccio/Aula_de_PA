# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escrever um programa que converte a temperatura de Celsios para Fahrenheit.
#
# F= (C x 9/5) + 32
#
# #Entrada
#
# Temperatura em Celsius
#
# #Processamento
#
# Converter Celsius para fahrenheit
#
# #Saída
#
# Mostrar a temperatura em fahrenheit

# %% [markdown]
# # Exercicio de exemplo

# %%
# Calcular a área do retângulo

comprimento = float (input("Digite o valor do comprimento:"))
altura = float (input("Digite o valor da altura:"))

# Processamento

area = comprimento * altura

# Saída

print(f"A área do retângulo é igual : {area}")
# Out:
# Digite o valor do comprimento:6.5
# Digite o valor da altura:3.5
# A área do retângulo é igual : 22.75

# %% [markdown]
# # Cadastro de usuário

# %%
# Cadastro de usuário símples

# Entrada

nome = str (input("digite seu nome: "))
idade = int (input("digite sua idade: "))
altura = float (input("digite su altura: "))
solteira = True

# Saída

print (f"Olá {nome}., ")
print (f"Você tem {idade} anos e {altura} metros de altura!")
print (f"solteira ")
# Out:
# digite seu nome: gabriela
# digite sua idade: 15
# digite su altura: 1.64
# Olá gabriela.,
# Você tem 15 anos e 1.64 metros de altura!
# solteira:

# %% [markdown]
# # Escrevendo um programa que converte a temperatura de Celsios para Fahrenheit.

# %%
# Calcular temperatura de Celsius para Fahrenheit

# Entrada

celsius =  float(input("Digite a temperatura em Celsius:"))

# Processamento

fahrenheit = (celsius  * 9/5) + 32

# Saída

print (f"{celsius}°C é igual a {fahrenheit}°F")
# Out:
# Digite a temperatura em Celsius:18
# 18.0°C é igual a 64.4°F

# %% [markdown]
# # Operadores aritiméticos
#
#
# "+" Soma
#
# "-" Subtração
#
# "*" Multiplicação
#
# / Divisão
#
# // Divisão inteira
#
# % Resto da Divisão
#
# ** Potência
#
#
#
# # Operadores relacionais
#
#
# == Igual
#
# != Diferente
#
# > Maior
#
# < Menor
#
# >= Maior ou igual
#
# <= Menor ou igual
#
#
# # Operadores lógicos
#
# and "e"
#
# or "ou"
#
# not "não"

# %% [markdown]
# # Calculadora Símples

# %%
# Calculadora Símples

# Entrada 2 valores
# Processamento calcular usando operadores aritiméticos
# Saída Mostrar o resultado

# Entrada

numero1 = int (input("digite um número: "))
numero2 = int (input("digite o segundo número: "))

# Processamento

soma = numero1 + numero2
subtração = numero1 - numero2
multiplicação = numero1 * numero2
divisão = numero1 / numero2
div_inteira = numero1 // numero2
resto = numero1 % numero2
potência = numero1 ** numero2

# Saída

print (f"O resultado da soma de {numero1} e {numero2} é igual: {soma}")
print (f"O resultado da subtração de {numero1} e {numero2} é igual: {subtração}")
print (f"O resultado da multiplicação de {numero1} e {numero2} é igual: {multiplicação}")
print (f"O resultado da divisão de {numero1} e {numero2} é igual: {divisão}")
print (f"O resultado da divisão inteira de {numero1} e {numero2} é igual: {div_inteira}")
print (f"O resto da diviusão  de {numero1} e {numero2} é igual: {resto}")
print (f"O resultado da potência de {numero1} e {numero2} é igual: {potência}")
# Out:
# digite um número: 3
# digite o segundo número: 4
# O resultado da soma de 3 e 4 é igual: 7
# O resultado da subtração de 3 e 4 é igual: -1
# O resultado da multiplicação de 3 e 4 é igual: 12
# O resultado da divisão de 3 e 4 é igual: 0.75
# O resultado da divisão inteira de 3 e 4 é igual: 0
# O resto da diviusão  de 3 e 4 é igual: 3
# O resultado da potência de 3 e 4 é igual: 81
