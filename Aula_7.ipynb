# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que indentifica se é par ou ímpar

# Entrada

numero = int(input("Digite um número :"))

# Processamento/Saída

if numero % 2 == 0:

  print(f" O número {numero} é par")

else:
  print(f" O número {numero} e ímpar")
# Out:
# Digite um número :2
#  O número 2 é par

# %%
# Escrever um programa que verifica as notas dos 4 bimestres e calcula a média do aluno

# Não permitir que o úsuario digite menores que zero ou maiores que dez
# Média menor que 5 - reprovado
# Média maior que 5 e menor que 7 - recuperação
# Média maior que 7 e menor que 10 - aprovado


# Entrada

nota_1 = float(input ("Digite a nota do 1° Bimestre "))
if nota_1 < 0 or nota_1 > 10:
  print("nota inválida, digite uma nota de 0 a 10:")


nota_2 = float(input ("Digite a nota do 2° Bimestre "))
if nota_2 < 0 or nota_2 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")


nota_3 = float(input ("Digite a nota do 3° Bimestre "))
if nota_3 < 0 or nota_3 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")

nota_4 = float(input ("Digite a nota do 4° Bimestre "))
if nota_4 < 0 or nota_4 > 10:
   print("nota inválida, digite uma nota de 0 a 10:")

# Processamento/Saída

media = (nota_1 + nota_2 + nota_3 + nota_4) /4

if media < 5:
    print(f"Você está reprovado, sua media é :{media} ")

elif media <= 7:
    print(f"Você está de recuperação, sua mediaa é {media}")

else:
    print(f"Você está aprovado, sua media é {media}")
# Out:
# Digite a nota do 1° Bimestre 10
# Digite a nota do 2° Bimestre 10
# Digite a nota do 3° Bimestre 10
# Digite a nota do 4° Bimestre 10
# Você está aprovado, sua media é 10.0

# %%
# Escrever um programa que leia o valor da compra e aplique:
# Até R$ 100 - sem desconto
# R$ 101 - a R$ 500 - 10% de desconto
# Aciima de R$ 500 - desconto de 20%

# mostrar valor a pagar depois de aplicado o desconto.

# Entrada
compra= float(input("Digite o valor da sua compra: R$ "))

desconto = compra - (compra * 0.10)


# Processamento/Saída

if compra > 100:
  desconto = compra - (compra * 0.10)
  print(f" O valor a pagar é:{desconto}")


elif compra > 500:
  desconto = compra - (compra * 0.20)
  print(f" O valor a pagar é:{desconto}")

else:
  print(f"Você não obteve desconto, o valor a pagar: {comnpra}")
# Out:
# Digite o valor da sua compra: R$ 1000
#  O valor a pagar é:900.0
