# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
#
# * Cálcular uma área
#
# # Entrada
#
# Ler lado1
#
# Ler lado2
#
# #processamento
#
# área = lado1 * lado2
#
# # Saída
#
# escrever o total da área

# %%
# Variáveis que recebe o valor dos lados

# Entrada
lado_1 = 7
lado_2 = 3

# %%
# Processamento

area = lado_1 * lado_2

# %%
# Saída

print (f"O total da área calculada: {area} metros quadrados")
# Out:
# O total da área calculada: 21 metros quadrados

# %% [markdown]
# Operadores aritiméticos:
#
#
#
# 1.   Soma = +
# 2.   Subtração = -
# 3.   Multiplicação = *
# 4.   Divisão = /

# %% [markdown]
# Atividade
#
# Fazer um algoritímo e depois o programa que recebe 4 notas do aluno e calcula a média aritimética e imprimi a média.

# %%
# Notas do aluno

# Entrada
nota_1 = 9
nota_2 = 6
nota_3 = 10
nota_4 = 9

# %%
# Processamento

media = nota_1 + nota_2 + nota_3 + nota_4
resultado = media /4

# %%
# Saída

print (f"Nota final do aluno: {resultado}")
# Out:
# Nota final do aluno: 8.5

# %% [markdown]
# Faça um algoritímo que receba um número e calcule o dobro desse número

# %%
# Váriaveis que recebe um valor e depois calcula o seu dobro

# Entrada

numero = 12

# %%
# Processamento
total = 12 * 2

# %%
# Saída

print (f" Valor final: {total}")
# Out:
#  Valor final: 24
