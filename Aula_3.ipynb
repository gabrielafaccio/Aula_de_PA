# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 Aula de Programação e

# %% [markdown]
# Aula de Programação e Algoritimo
# * Introdução em Programação

# %%
print ('Olâ Mundo')
# Out:
# Olâ Mundo

# %%
a = 5
b = 6
t = a + b

# %%
print (t)
# Out:
# 11

# %% [markdown]
# #TIPOS NÚMERICOS

# %%
idade = 15 # int

# %%
altura = 1.65 # float

# %%
numero_complexo = 2 + 3j # complex

# %% [markdown]
# #TIPO TEXTO

# %%
nome = "Gabriela" # str

# %% [markdown]
# # TIPO BOOLEANO

# %%
esta_chovendo = False # bool

# %% [markdown]
# #TIPO LISTA (MUTÁVEL)

# %%
numeros = [1, 2, 3, 4, 5] # List

# %% [markdown]
# # TIPO TUPLA (IMUTÁVEL)

# %%
coordenadas = (10, 20) # tuple

# %% [markdown]
# #TIPO CONJUNTO (VALORES ÚNICOS)

# %%
vogais = {'a', 'e', 'i', 'o','u'} # set

# %% [markdown]
# # TIPO DICIONÁRIO (CHAVE-VALOR)

# %%
pessoa = {"nome": "Carlos", "idade": 30} # dict

# %% [markdown]
# PRINT

# %%
print(f"Nome: {nome}, Idade: {idade}, Altura: {altura}")
# Out:
# Nome: Gabriela, Idade: 15, Altura: 1.65
