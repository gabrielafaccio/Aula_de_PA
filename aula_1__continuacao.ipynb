# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielafaccio/Aula_de_PA/blob/main/aula_1__continuacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXERCíCIOS PARA SEREM REALIZADOS NO COLAB

# %% [markdown]
# **Exercício 1** – Dados Pessoais
# Crie um programa que solicite ao usuário:
#
#  Nome;
#
#  Idade;
#
#
#  Cidade.
# Ao final, exiba uma mensagem informando o nome, a idade e a cidade do usuário.

# %%
nome = str(input("Digite o seu nome:"))

cidade = str(input("Digite a sua cidade:"))

print (f"Seu nome é {nome},e sua cidade é {cidade}, certo?: ")
# Out:
# Digite o seu nome:gabriela
# Digite a sua cidade:sp
# Seu nome é gabriela ,e sua cidade é sp, certo?:

# %% [markdown]
# **Exercício 2** – Antecessor e Sucessor
# Solicite um número inteiro ao usuário e exiba:
#
#  O número informado;
#
#  Seu antecessor;
#
#  Seu sucessor.

# %%
# Exercício 2 – Antecessor e Sucessor

numero = int(input("Digite um número inteiro: "))

print("Número informado:", numero)
print("Antecessor:", numero - 1)
print("Sucessor:", numero + 1)

# %% [markdown]
# **Exercício 3** – Operações Matemáticas
# Solicite dois números e apresente os seguintes resultados:
#
#  Soma;
#
#  Subtração;
#
#  Multiplicação;
#
#  Divisão.

# %%
n1 = int(input("digite o primeiro número: "))
n2 = int(input("digite o segundo número: "))

soma = (n1 + n2)
divisao = (n1 / n2)
subtracao = (n1 - n2)
multiplicacao = (n1 * n2)

print(f"Soma: {soma}")
print(f"Subtração: {subtracao}")
print(f"Multiplicação: {multiplicacao}")
print(f"Divisão: {divisao}")
# Out:
# digite o primeiro número: 10
# digite o segundo número: 20
# Soma: 30
# Subtração: -10
# Multiplicação: 200
# Divisão: 0.5

# %% [markdown]
# **Exercício 4** – Média de Notas
# Solicite três notas de um aluno.
# Calcule a média e informe a situação do aluno conforme os critérios:
#
#  Média maior ou igual a 7: Aprovado;
#
#  Média entre 5 e 6,9: Recuperação;
#
#  Média menor que 5: Reprovado.

# %%
# Exercício 4 – Média de Notas

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))

media = (nota1 + nota2 + nota3) / 3

print("Média:", media)

if media >= 7:
    print("Situação: Aprovado")
elif media >= 5:
    print("Situação: Recuperação")
else:
    print("Situação: Reprovado")

# %% [markdown]
# **Exercício 5** – Conversão de Temperatura
# Solicite uma temperatura em graus Celsius e converta o valor para Fahrenheit.
# Exiba a temperatura convertida.

# %%
# Exercício 5 – Conversão de Temperatura

celsius = float(input("Digite a temperatura em graus Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperatura em Fahrenheit:", fahrenheit, "°F")

# %% [markdown]
# **Exercício 6 **– Área de um Retângulo
#
# Solicite a base e a altura de um retângulo.
#
# Calcule e exiba a área do retângulo.

# %%
# Exercício 6 – Área de um Retângulo

base = float(input("Digite a base do retângulo: "))
altura = float(input("Digite a altura do retângulo: "))

area = base * altura

print("A área do retângulo é:", area)

# %% [markdown]
# **Exercício 7** – Número Par ou Ímpar
# Solicite um número inteiro e informe se ele é:
#
#  Par;
#
#  Ímpar.

# %%
# Exercício 7 – Número Par ou Ímpar

numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
    print("O número é Par.")
else:
    print("O número é Ímpar.")

# %% [markdown]
# **Exercício 8 **– Maior Número
#
# Solicite três números diferentes.
#
# Determine e exiba qual deles é o maior.

# %%
# Exercício 8 – Maior Número

num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
num3 = float(input("Digite o terceiro número: "))

if num1 > num2 and num1 > num3:
    print("O maior número é:", num1)
elif num2 > num1 and num2 > num3:
    print("O maior número é:", num2)
else:
    print("O maior número é:", num3)

# %% [markdown]
# **Exercício 9** – Tabuada
#
# Solicite um número inteiro e exiba sua tabuada de 1 até 10.

# %%
numero = int(input("Digite um número: "))

for i in range (0,11):
  print(f"{numero} + {i} = {numero + i}")

# %% [markdown]
# **Exercício 10 **– Calculadora Simples
#
# Solicite dois números e uma operação matemática (+, -, * ou /).
#
# Realize a operação escolhida e exiba o resultado correspondente

# %%
# Exercício 10 – Calculadora Simples

num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
operacao = input("Digite a operação (+, -, * ou /): ")

if operacao == "+":
    resultado = num1 + num2
    print("Resultado:", resultado)

elif operacao == "-":
    resultado = num1 - num2
    print("Resultado:", resultado)

elif operacao == "*":
    resultado = num1 * num2
    print("Resultado:", resultado)

elif operacao == "/":
    if num2 != 0:
        resultado = num1 / num2
        print("Resultado:", resultado)
    else:
        print("Erro: divisão por zero não é permitida.")

else:
    print("Operação inválida.")
